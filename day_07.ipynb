# %% [markdown]
# # Day 7
#
# ## part 1
#
# - Elephants stole the operators! (lol, wat?!)
# - `+` and `*` can  e inserted
# - operations are evaluated left-to-right
# - find the sum of the test values from the equations that are possible to solve.

# %%
from dataclasses import dataclass
import logging

from tqdm import  tqdm

from advent_of_code_utils.advent_of_code_utils import (
    parse_from_file, ParseConfig as PC, markdown
)

log = logging.getLogger('day 7')
logging.basicConfig(level=logging.INFO)

# %%
parser = PC('\n', PC(': ', [int, PC(' ', int)]))

example = parse_from_file('day_7_example.txt', parser)

@dataclass
class Equation:
    total: int
    operands: list[int]
    operators: list[str] = None

    @property
    def combinations(self) -> list[list[str]]:
        """
        returns an iterable of all combinations of + and * operators for the
        equation
        """
        ops = ['+', '*']
        slots = len(self.operands) - 1
        log.debug(f'genearting combinations for {slots=}')
        combs = []
        for value in range(pow(2, slots)):
            temp = []
            for char in f'{value:0{slots}b}':
                temp.append(ops[int(char)])
            combs.append(temp)
        log.debug(f'{len(combs)} operator combinations generated')
        return combs
    
    def solve(self, operators: list[str]) -> int:
        """returns the result from applying the operands"""
        log.debug(f'solving with {operators=}')
        total = self.operands[0]
        log.debug(f'{total=}')
        ops = [op for op in operators]
        for value in self.operands[1:]:
            op = ops.pop(0)
            match(op):
                case '+':
                    total += value
                case '*':
                    total *= value
                case _:
                    ValueError(f'Operator not recognised: {op}')
            log.debug(f'{op}= {value} -> {total=}')
        return total
    
    def find_ops(self) -> None:
        """tests operands to try and solve the equation"""
        log.debug(f'attempting to solve: {self}')
        for combination in self.combinations:
            log.debug(f'testing {combination=}')
            if self.solve(combination) == self.total:
                self.operators = combination
                log.debug('solution found!')
                break
        else:
            log.debug('no solution found!')


example_eqs = [Equation(t, o) for t, o in example]
# Out:
# INFO:advent_of_code_utils.py:9 items loaded from "day_7_example.txt"

# %%
log.setLevel(logging.DEBUG)
for eq in example_eqs[1:3]:
    eq.find_ops()
    log.info(f'updated equation: {eq}')
# Out:
# DEBUG:day 7:attempting to solve: Equation(total=3267, operands=[81, 40, 27], operators=None)
# DEBUG:day 7:genearting combinations for slots=2
# DEBUG:day 7:4 operator combinations generated
# DEBUG:day 7:testing combination=['+', '+']
# DEBUG:day 7:solving with operators=['+', '+']
# DEBUG:day 7:total=81
# DEBUG:day 7:+= 40 -> total=121
# DEBUG:day 7:+= 27 -> total=148
# DEBUG:day 7:testing combination=['+', '*']
# DEBUG:day 7:solving with operators=['+', '*']
# DEBUG:day 7:total=81
# DEBUG:day 7:+= 40 -> total=121
# DEBUG:day 7:*= 27 -> total=3267
# DEBUG:day 7:solution found!
# INFO:day 7:updated equation: Equation(total=3267, operands=[81, 40, 27], operators=['+', '*'])
# DEBUG:day 7:attempting to solve: Equation(total=83, operands=[17, 5], operators=None)
# DEBUG:day 7:genearting combinations for slots=1
# DEBUG:day 7:2 operator combinations generated
# DEBUG:day 7:testing combination=['+']
# DEBUG:day 7:solving with operators=['+']
# DEBUG:day 7:total=17
# DEBUG:day 7:+= 5 -> total=22
# DEBUG:day 7:testing combination=['*']
# DEBUG:day 7:solving with operators=['*']
# DEBUG:day 7:total=17
# DEBUG:day 7:*= 5 -> total=85
# DEBUG:day 7:no solution found!
# INFO:day 7:updated equation: Equation(total=83, operands=[17, 5], operators=None)

# %%
# cool so let's try solving the exmaple
log.setLevel(logging.INFO)
for eq in example_eqs:
    eq.find_ops()
example_total_cal = sum(
    (eq.total for eq in example_eqs if eq.operators is not None))
log.info(f'the total example calibration is: {example_total_cal}')
# Out:
# INFO:day 7:the total example calibration is: 3749

# %%
# ok nice that works so let's solve for real!
puzzle_input = parse_from_file('day_7.txt', parser)
equations = [Equation(t, o) for t, o in puzzle_input]
log.info(f'loaded {len(equations)} equations')
for eq in tqdm(equations, desc='finding operators'):
    eq.find_ops()
log.info('finding total calibration value')
total_cal = sum(
    (eq.total for eq in equations if eq.operators is not None))
markdown(f'the total calibration result is: {total_cal}')
# Out:
# INFO:advent_of_code_utils.py:850 items loaded from "day_7.txt"
# INFO:day 7:loaded 850 equations
# finding operators: 100%|██████████| 850/850 [00:04<00:00, 180.26it/s]
# INFO:day 7:finding total calibration value
# the total calibration result is: 5702958180383

# %% [markdown]
# ## part 2
#
# - `||` yo new op just dropped! It concatenates numbers.
# - Recompute theh total calibration result with this new operator in the mix

# %%
# the ones that already solve don't need to be reconsidered
ex_subset = [eq for eq in example_eqs if eq.operators is None]

# %%
class AdvancedEquation(Equation):
    """like an equation but more!"""
    def solve(self, operators: list[str]) -> int:
        """returns the result from applying the operands"""
        log.debug(f'solving with {operators=}')
        total = self.operands[0]
        log.debug(f'{total=}')
        ops = [op for op in operators]
        for value in self.operands[1:]:
            op = ops.pop(0)
            match(op):
                case '+':
                    total += value
                case '*':
                    total *= value
                case '||':
                    total = int(f'{total}{value}')
                case _:
                    ValueError(f'Operator not recognised: {op}')
            log.debug(f'{op}= {value} -> {total=}')
        return total
    
    @property
    def combinations(self) -> list[list[str]]:
        """
        returns an iterable of all combinations of +, * and || operators for
        the equation
        """
        ops = ['+', '*', '||']
        slots = len(self.operands) - 1
        log.debug(f'genearting combinations for {slots=}')
        combs = []
        # this should work up to base 10 - not that it needs to!
        for value in range(pow(len(ops), slots)):
            # for each value generate a string in that base
            temp = value
            digit_str = ''
            for power in reversed(range(slots)):
                count = 0
                sub = pow(len(ops), power)
                while temp - sub >= 0:
                    temp -= sub
                    count += 1
                digit_str += str(count)
            log.debug(f'{digit_str=}')
            # then we can do the same as before assigning an op per each digit
            temp = []
            for char in digit_str:
                temp.append(ops[int(char)])
            combs.append(temp)
        log.debug(f'{len(combs)} operator combinations generated')
        return combs

log.setLevel(logging.DEBUG)
ex_ad_eqs = [AdvancedEquation(eq.total, eq.operands) for eq in ex_subset]
for eq in ex_ad_eqs:
    eq.find_ops()
new_ex_total = sum((
    eq.total for eq in ex_ad_eqs if eq.operators is not None
))
log.info(
    f'{new_ex_total=} so combined total is {new_ex_total + example_total_cal}')
# Out:
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=83, operands=[17, 5], operators=None)
# DEBUG:day 7:genearting combinations for slots=1
# DEBUG:day 7:digit_str='0'
# DEBUG:day 7:digit_str='1'
# DEBUG:day 7:digit_str='2'
# DEBUG:day 7:3 operator combinations generated
# DEBUG:day 7:testing combination=['+']
# DEBUG:day 7:solving with operators=['+']
# DEBUG:day 7:total=17
# DEBUG:day 7:+= 5 -> total=22
# DEBUG:day 7:testing combination=['*']
# DEBUG:day 7:solving with operators=['*']
# DEBUG:day 7:total=17
# DEBUG:day 7:*= 5 -> total=85
# DEBUG:day 7:testing combination=['||']
# DEBUG:day 7:solving with operators=['||']
# DEBUG:day 7:total=17
# DEBUG:day 7:||= 5 -> total=175
# DEBUG:day 7:no solution found!
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=156, operands=[15, 6], operators=None)
# DEBUG:day 7:genearting combinations for slots=1
# DEBUG:day 7:digit_str='0'
# DEBUG:day 7:digit_str='1'
# DEBUG:day 7:digit_str='2'
# DEBUG:day 7:3 operator combinations generated
# DEBUG:day 7:testing combination=['+']
# DEBUG:day 7:solving with operators=['+']
# DEBUG:day 7:total=15
# DEBUG:day 7:+= 6 -> total=21
# DEBUG:day 7:testing combination=['*']
# DEBUG:day 7:solving with operators=['*']
# DEBUG:day 7:total=15
# DEBUG:day 7:*= 6 -> total=90
# DEBUG:day 7:testing combination=['||']
# DEBUG:day 7:solving with operators=['||']
# DEBUG:day 7:total=15
# DEBUG:day 7:||= 6 -> total=156
# DEBUG:day 7:solution found!
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=7290, operands=[6, 8, 6, 15], operators=None)
# DEBUG:day 7:genearting combinations for slots=3
# DEBUG:day 7:digit_str='000'
# DEBUG:day 7:digit_str='001'
# DEBUG:day 7:digit_str='002'
# DEBUG:day 7:digit_str='010'
# DEBUG:day 7:digit_str='011'
# DEBUG:day 7:digit_str='012'
# DEBUG:day 7:digit_str='020'
# DEBUG:day 7:digit_str='021'
# DEBUG:day 7:digit_str='022'
# DEBUG:day 7:digit_str='100'
# DEBUG:day 7:digit_str='101'
# DEBUG:day 7:digit_str='102'
# DEBUG:day 7:digit_str='110'
# DEBUG:day 7:digit_str='111'
# DEBUG:day 7:digit_str='112'
# DEBUG:day 7:digit_str='120'
# DEBUG:day 7:digit_str='121'
# DEBUG:day 7:digit_str='122'
# DEBUG:day 7:digit_str='200'
# DEBUG:day 7:digit_str='201'
# DEBUG:day 7:digit_str='202'
# DEBUG:day 7:digit_str='210'
# DEBUG:day 7:digit_str='211'
# DEBUG:day 7:digit_str='212'
# DEBUG:day 7:digit_str='220'
# DEBUG:day 7:digit_str='221'
# DEBUG:day 7:digit_str='222'
# DEBUG:day 7:27 operator combinations generated
# DEBUG:day 7:testing combination=['+', '+', '+']
# DEBUG:day 7:solving with operators=['+', '+', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:+= 6 -> total=20
# DEBUG:day 7:+= 15 -> total=35
# DEBUG:day 7:testing combination=['+', '+', '*']
# DEBUG:day 7:solving with operators=['+', '+', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:+= 6 -> total=20
# DEBUG:day 7:*= 15 -> total=300
# DEBUG:day 7:testing combination=['+', '+', '||']
# DEBUG:day 7:solving with operators=['+', '+', '||']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:+= 6 -> total=20
# DEBUG:day 7:||= 15 -> total=2015
# DEBUG:day 7:testing combination=['+', '*', '+']
# DEBUG:day 7:solving with operators=['+', '*', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:*= 6 -> total=84
# DEBUG:day 7:+= 15 -> total=99
# DEBUG:day 7:testing combination=['+', '*', '*']
# DEBUG:day 7:solving with operators=['+', '*', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:*= 6 -> total=84
# DEBUG:day 7:*= 15 -> total=1260
# DEBUG:day 7:testing combination=['+', '*', '||']
# DEBUG:day 7:solving with operators=['+', '*', '||']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:*= 6 -> total=84
# DEBUG:day 7:||= 15 -> total=8415
# DEBUG:day 7:testing combination=['+', '||', '+']
# DEBUG:day 7:solving with operators=['+', '||', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:||= 6 -> total=146
# DEBUG:day 7:+= 15 -> total=161
# DEBUG:day 7:testing combination=['+', '||', '*']
# DEBUG:day 7:solving with operators=['+', '||', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:||= 6 -> total=146
# DEBUG:day 7:*= 15 -> total=2190
# DEBUG:day 7:testing combination=['+', '||', '||']
# DEBUG:day 7:solving with operators=['+', '||', '||']
# DEBUG:day 7:total=6
# DEBUG:day 7:+= 8 -> total=14
# DEBUG:day 7:||= 6 -> total=146
# DEBUG:day 7:||= 15 -> total=14615
# DEBUG:day 7:testing combination=['*', '+', '+']
# DEBUG:day 7:solving with operators=['*', '+', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:+= 6 -> total=54
# DEBUG:day 7:+= 15 -> total=69
# DEBUG:day 7:testing combination=['*', '+', '*']
# DEBUG:day 7:solving with operators=['*', '+', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:+= 6 -> total=54
# DEBUG:day 7:*= 15 -> total=810
# DEBUG:day 7:testing combination=['*', '+', '||']
# DEBUG:day 7:solving with operators=['*', '+', '||']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:+= 6 -> total=54
# DEBUG:day 7:||= 15 -> total=5415
# DEBUG:day 7:testing combination=['*', '*', '+']
# DEBUG:day 7:solving with operators=['*', '*', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:*= 6 -> total=288
# DEBUG:day 7:+= 15 -> total=303
# DEBUG:day 7:testing combination=['*', '*', '*']
# DEBUG:day 7:solving with operators=['*', '*', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:*= 6 -> total=288
# DEBUG:day 7:*= 15 -> total=4320
# DEBUG:day 7:testing combination=['*', '*', '||']
# DEBUG:day 7:solving with operators=['*', '*', '||']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:*= 6 -> total=288
# DEBUG:day 7:||= 15 -> total=28815
# DEBUG:day 7:testing combination=['*', '||', '+']
# DEBUG:day 7:solving with operators=['*', '||', '+']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:||= 6 -> total=486
# DEBUG:day 7:+= 15 -> total=501
# DEBUG:day 7:testing combination=['*', '||', '*']
# DEBUG:day 7:solving with operators=['*', '||', '*']
# DEBUG:day 7:total=6
# DEBUG:day 7:*= 8 -> total=48
# DEBUG:day 7:||= 6 -> total=486
# DEBUG:day 7:*= 15 -> total=7290
# DEBUG:day 7:solution found!
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=161011, operands=[16, 10, 13], operators=None)
# DEBUG:day 7:genearting combinations for slots=2
# DEBUG:day 7:digit_str='00'
# DEBUG:day 7:digit_str='01'
# DEBUG:day 7:digit_str='02'
# DEBUG:day 7:digit_str='10'
# DEBUG:day 7:digit_str='11'
# DEBUG:day 7:digit_str='12'
# DEBUG:day 7:digit_str='20'
# DEBUG:day 7:digit_str='21'
# DEBUG:day 7:digit_str='22'
# DEBUG:day 7:9 operator combinations generated
# DEBUG:day 7:testing combination=['+', '+']
# DEBUG:day 7:solving with operators=['+', '+']
# DEBUG:day 7:total=16
# DEBUG:day 7:+= 10 -> total=26
# DEBUG:day 7:+= 13 -> total=39
# DEBUG:day 7:testing combination=['+', '*']
# DEBUG:day 7:solving with operators=['+', '*']
# DEBUG:day 7:total=16
# DEBUG:day 7:+= 10 -> total=26
# DEBUG:day 7:*= 13 -> total=338
# DEBUG:day 7:testing combination=['+', '||']
# DEBUG:day 7:solving with operators=['+', '||']
# DEBUG:day 7:total=16
# DEBUG:day 7:+= 10 -> total=26
# DEBUG:day 7:||= 13 -> total=2613
# DEBUG:day 7:testing combination=['*', '+']
# DEBUG:day 7:solving with operators=['*', '+']
# DEBUG:day 7:total=16
# DEBUG:day 7:*= 10 -> total=160
# DEBUG:day 7:+= 13 -> total=173
# DEBUG:day 7:testing combination=['*', '*']
# DEBUG:day 7:solving with operators=['*', '*']
# DEBUG:day 7:total=16
# DEBUG:day 7:*= 10 -> total=160
# DEBUG:day 7:*= 13 -> total=2080
# DEBUG:day 7:testing combination=['*', '||']
# DEBUG:day 7:solving with operators=['*', '||']
# DEBUG:day 7:total=16
# DEBUG:day 7:*= 10 -> total=160
# DEBUG:day 7:||= 13 -> total=16013
# DEBUG:day 7:testing combination=['||', '+']
# DEBUG:day 7:solving with operators=['||', '+']
# DEBUG:day 7:total=16
# DEBUG:day 7:||= 10 -> total=1610
# DEBUG:day 7:+= 13 -> total=1623
# DEBUG:day 7:testing combination=['||', '*']
# DEBUG:day 7:solving with operators=['||', '*']
# DEBUG:day 7:total=16
# DEBUG:day 7:||= 10 -> total=1610
# DEBUG:day 7:*= 13 -> total=20930
# DEBUG:day 7:testing combination=['||', '||']
# DEBUG:day 7:solving with operators=['||', '||']
# DEBUG:day 7:total=16
# DEBUG:day 7:||= 10 -> total=1610
# DEBUG:day 7:||= 13 -> total=161013
# DEBUG:day 7:no solution found!
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=192, operands=[17, 8, 14], operators=None)
# DEBUG:day 7:genearting combinations for slots=2
# DEBUG:day 7:digit_str='00'
# DEBUG:day 7:digit_str='01'
# DEBUG:day 7:digit_str='02'
# DEBUG:day 7:digit_str='10'
# DEBUG:day 7:digit_str='11'
# DEBUG:day 7:digit_str='12'
# DEBUG:day 7:digit_str='20'
# DEBUG:day 7:digit_str='21'
# DEBUG:day 7:digit_str='22'
# DEBUG:day 7:9 operator combinations generated
# DEBUG:day 7:testing combination=['+', '+']
# DEBUG:day 7:solving with operators=['+', '+']
# DEBUG:day 7:total=17
# DEBUG:day 7:+= 8 -> total=25
# DEBUG:day 7:+= 14 -> total=39
# DEBUG:day 7:testing combination=['+', '*']
# DEBUG:day 7:solving with operators=['+', '*']
# DEBUG:day 7:total=17
# DEBUG:day 7:+= 8 -> total=25
# DEBUG:day 7:*= 14 -> total=350
# DEBUG:day 7:testing combination=['+', '||']
# DEBUG:day 7:solving with operators=['+', '||']
# DEBUG:day 7:total=17
# DEBUG:day 7:+= 8 -> total=25
# DEBUG:day 7:||= 14 -> total=2514
# DEBUG:day 7:testing combination=['*', '+']
# DEBUG:day 7:solving with operators=['*', '+']
# DEBUG:day 7:total=17
# DEBUG:day 7:*= 8 -> total=136
# DEBUG:day 7:+= 14 -> total=150
# DEBUG:day 7:testing combination=['*', '*']
# DEBUG:day 7:solving with operators=['*', '*']
# DEBUG:day 7:total=17
# DEBUG:day 7:*= 8 -> total=136
# DEBUG:day 7:*= 14 -> total=1904
# DEBUG:day 7:testing combination=['*', '||']
# DEBUG:day 7:solving with operators=['*', '||']
# DEBUG:day 7:total=17
# DEBUG:day 7:*= 8 -> total=136
# DEBUG:day 7:||= 14 -> total=13614
# DEBUG:day 7:testing combination=['||', '+']
# DEBUG:day 7:solving with operators=['||', '+']
# DEBUG:day 7:total=17
# DEBUG:day 7:||= 8 -> total=178
# DEBUG:day 7:+= 14 -> total=192
# DEBUG:day 7:solution found!
# DEBUG:day 7:attempting to solve: AdvancedEquation(total=21037, operands=[9, 7, 18, 13], operators=None)
# DEBUG:day 7:genearting combinations for slots=3
# DEBUG:day 7:digit_str='000'
# DEBUG:day 7:digit_str='001'
# DEBUG:day 7:digit_str='002'
# DEBUG:day 7:digit_str='010'
# DEBUG:day 7:digit_str='011'
# DEBUG:day 7:digit_str='012'
# DEBUG:day 7:digit_str='020'
# DEBUG:day 7:digit_str='021'
# DEBUG:day 7:digit_str='022'
# DEBUG:day 7:digit_str='100'
# DEBUG:day 7:digit_str='101'
# DEBUG:day 7:digit_str='102'
# DEBUG:day 7:digit_str='110'
# DEBUG:day 7:digit_str='111'
# DEBUG:day 7:digit_str='112'
# DEBUG:day 7:digit_str='120'
# DEBUG:day 7:digit_str='121'
# DEBUG:day 7:digit_str='122'
# DEBUG:day 7:digit_str='200'
# DEBUG:day 7:digit_str='201'
# DEBUG:day 7:digit_str='202'
# DEBUG:day 7:digit_str='210'
# DEBUG:day 7:digit_str='211'
# DEBUG:day 7:digit_str='212'
# DEBUG:day 7:digit_str='220'
# DEBUG:day 7:digit_str='221'
# DEBUG:day 7:digit_str='222'
# DEBUG:day 7:27 operator combinations generated
# DEBUG:day 7:testing combination=['+', '+', '+']
# DEBUG:day 7:solving with operators=['+', '+', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:+= 18 -> total=34
# DEBUG:day 7:+= 13 -> total=47
# DEBUG:day 7:testing combination=['+', '+', '*']
# DEBUG:day 7:solving with operators=['+', '+', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:+= 18 -> total=34
# DEBUG:day 7:*= 13 -> total=442
# DEBUG:day 7:testing combination=['+', '+', '||']
# DEBUG:day 7:solving with operators=['+', '+', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:+= 18 -> total=34
# DEBUG:day 7:||= 13 -> total=3413
# DEBUG:day 7:testing combination=['+', '*', '+']
# DEBUG:day 7:solving with operators=['+', '*', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:*= 18 -> total=288
# DEBUG:day 7:+= 13 -> total=301
# DEBUG:day 7:testing combination=['+', '*', '*']
# DEBUG:day 7:solving with operators=['+', '*', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:*= 18 -> total=288
# DEBUG:day 7:*= 13 -> total=3744
# DEBUG:day 7:testing combination=['+', '*', '||']
# DEBUG:day 7:solving with operators=['+', '*', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:*= 18 -> total=288
# DEBUG:day 7:||= 13 -> total=28813
# DEBUG:day 7:testing combination=['+', '||', '+']
# DEBUG:day 7:solving with operators=['+', '||', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:||= 18 -> total=1618
# DEBUG:day 7:+= 13 -> total=1631
# DEBUG:day 7:testing combination=['+', '||', '*']
# DEBUG:day 7:solving with operators=['+', '||', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:||= 18 -> total=1618
# DEBUG:day 7:*= 13 -> total=21034
# DEBUG:day 7:testing combination=['+', '||', '||']
# DEBUG:day 7:solving with operators=['+', '||', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:+= 7 -> total=16
# DEBUG:day 7:||= 18 -> total=1618
# DEBUG:day 7:||= 13 -> total=161813
# DEBUG:day 7:testing combination=['*', '+', '+']
# DEBUG:day 7:solving with operators=['*', '+', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:+= 18 -> total=81
# DEBUG:day 7:+= 13 -> total=94
# DEBUG:day 7:testing combination=['*', '+', '*']
# DEBUG:day 7:solving with operators=['*', '+', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:+= 18 -> total=81
# DEBUG:day 7:*= 13 -> total=1053
# DEBUG:day 7:testing combination=['*', '+', '||']
# DEBUG:day 7:solving with operators=['*', '+', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:+= 18 -> total=81
# DEBUG:day 7:||= 13 -> total=8113
# DEBUG:day 7:testing combination=['*', '*', '+']
# DEBUG:day 7:solving with operators=['*', '*', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:*= 18 -> total=1134
# DEBUG:day 7:+= 13 -> total=1147
# DEBUG:day 7:testing combination=['*', '*', '*']
# DEBUG:day 7:solving with operators=['*', '*', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:*= 18 -> total=1134
# DEBUG:day 7:*= 13 -> total=14742
# DEBUG:day 7:testing combination=['*', '*', '||']
# DEBUG:day 7:solving with operators=['*', '*', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:*= 18 -> total=1134
# DEBUG:day 7:||= 13 -> total=113413
# DEBUG:day 7:testing combination=['*', '||', '+']
# DEBUG:day 7:solving with operators=['*', '||', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:||= 18 -> total=6318
# DEBUG:day 7:+= 13 -> total=6331
# DEBUG:day 7:testing combination=['*', '||', '*']
# DEBUG:day 7:solving with operators=['*', '||', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:||= 18 -> total=6318
# DEBUG:day 7:*= 13 -> total=82134
# DEBUG:day 7:testing combination=['*', '||', '||']
# DEBUG:day 7:solving with operators=['*', '||', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:*= 7 -> total=63
# DEBUG:day 7:||= 18 -> total=6318
# DEBUG:day 7:||= 13 -> total=631813
# DEBUG:day 7:testing combination=['||', '+', '+']
# DEBUG:day 7:solving with operators=['||', '+', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:+= 18 -> total=115
# DEBUG:day 7:+= 13 -> total=128
# DEBUG:day 7:testing combination=['||', '+', '*']
# DEBUG:day 7:solving with operators=['||', '+', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:+= 18 -> total=115
# DEBUG:day 7:*= 13 -> total=1495
# DEBUG:day 7:testing combination=['||', '+', '||']
# DEBUG:day 7:solving with operators=['||', '+', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:+= 18 -> total=115
# DEBUG:day 7:||= 13 -> total=11513
# DEBUG:day 7:testing combination=['||', '*', '+']
# DEBUG:day 7:solving with operators=['||', '*', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:*= 18 -> total=1746
# DEBUG:day 7:+= 13 -> total=1759
# DEBUG:day 7:testing combination=['||', '*', '*']
# DEBUG:day 7:solving with operators=['||', '*', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:*= 18 -> total=1746
# DEBUG:day 7:*= 13 -> total=22698
# DEBUG:day 7:testing combination=['||', '*', '||']
# DEBUG:day 7:solving with operators=['||', '*', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:*= 18 -> total=1746
# DEBUG:day 7:||= 13 -> total=174613
# DEBUG:day 7:testing combination=['||', '||', '+']
# DEBUG:day 7:solving with operators=['||', '||', '+']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:||= 18 -> total=9718
# DEBUG:day 7:+= 13 -> total=9731
# DEBUG:day 7:testing combination=['||', '||', '*']
# DEBUG:day 7:solving with operators=['||', '||', '*']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:||= 18 -> total=9718
# DEBUG:day 7:*= 13 -> total=126334
# DEBUG:day 7:testing combination=['||', '||', '||']
# DEBUG:day 7:solving with operators=['||', '||', '||']
# DEBUG:day 7:total=9
# DEBUG:day 7:||= 7 -> total=97
# DEBUG:day 7:||= 18 -> total=9718
# DEBUG:day 7:||= 13 -> total=971813
# DEBUG:day 7:no solution found!
# INFO:day 7:new_ex_total=7638 so combined total is 11387

# %%
# great that works! let's solve!
log.setLevel(logging.INFO)
ad_equations = [
    AdvancedEquation(eq.total, eq.operands) for eq in equations
    if eq.operators is None
]
log.info(f'converted {len(ad_equations)} to AdvancedEquation')
for eq in tqdm(ad_equations, desc='finding operators'):
    # had to run this again so just skip ones that are solved
    if eq.operators is not None:
        continue
    eq.find_ops()
# Out:
# INFO:day 7:converted 518 to AdvancedEquation
# finding operators: 100%|██████████| 518/518 [04:03<00:00,  2.12it/s]

# %%
log.info('finding additional total calibration value')
ad_total_cal = sum(
    (eq.total for eq in ad_equations if eq.operators is not None))
log.info(f'The advanced total cal result is: {ad_total_cal}')
markdown(f'the new total calibration result is: {total_cal + ad_total_cal}')
# Out:
# INFO:day 7:finding additional total calibration value
# INFO:day 7:The advanced total cal result is: 86909427938755
# the new total calibration result is: 92612386119138
